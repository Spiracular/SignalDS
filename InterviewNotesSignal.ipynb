# %% [markdown]
# # Signal Job Thing
#
# default is not getting a job (maybe don't think of it as a score beyond a boolean)
#
# It's not about **avoiding taking damage**, it's about **acquiring positive points** (hits?) that make them want to hire you.
#
# Think of it as making a sale, talk about why you'd be the best person for the job.
#
# **Hit points vs. Collecting yeses, Navigating minefields**
#
# Part 1: comfortable social stuff
# Part 2: technical questions
#
# Stories so they're memorable and easier to jusfity hiring to boss
#
# Typical acceptance rate of about 1/10? (context?)
#
# ~15% of first year's salary to recruiter
#
# *Applied Business Intelligence* (liked wording)
#
# **Context, Action, Result**
#
# Where/Setting/Background, Action, Result/Conclusion
#
# *Categories*
#
# Times, Types, Traits
#
# Early Examples:
# Times - Hobbies, Most recent job,
# Types - Volunteers, Learning, Personal growth, Failure, Tech expertise
# Traits - Leadership, Math, Organization, Short story, Logical thinking
#
# Better Examples:
# Times - Hobbies, Recent job, Past job, Education
# Types - Opener, Competence, Project completion, Failure, Tech expertise, Leadership, Passion
# Traits - Funny, Short story, Solo work, Group work, Work under pressure, Logical thinking, Critical thinking, Culture fit
#
#
# Types as things you tell, Traits as things you show.
#
# Resume build: top relevant experience on top, everything else after.
#
# One story can have several different morals [leadership, tech expertise, topic, ]
#
#
# 1-2 stories you know well enough that they put you at ease while you're telling them.
#
# Practice. (Kata = practice enough that they're sys-1 automated)
#
# Know core of story really well, flavor with things in "Better Examples".

# %% [markdown]
# ## Scratch paper and Common errors
#
# Roko's interview ended when he didn't know precision and time of last project
#
# Looking too overtly self-interested (ex: vacation questions)
#
# (Look symbiotic, not parasitic)
#
# Academic trap: business people have a semi-irrational fear of interesting people (sorry, people who just want to do interesting things). See also:
#
# Don't talk about ML? Can talk about what you did for particular projects.
#
# Lot of people think about contributions, not value. Think about value. "Will make $X for company," business-thinking, relatively-shorter time horizons.
#
# [not maximum likelihood... damn it, what is it called? = posterior likelihood]

# %% [markdown]
# # **Job Types, "Most valuable thing I've done," and Stories**
#
#
# ## Job Types
#
# Lab, Museum, Teaching, Data Sci(subtype?), Data storytelling? (...really? Okay, really. Fine.)
#
# ## Valuable things
#
# Used RevBayes to take DNA data from a group of gall wasps and output the highest posterior-likelihood phylogenies under different evolutionary-rate-change assumptions (strict clock vs. relaxed clock), then perform stepping-stone and path-finding analyses to get marginal likelihoods associated with the multiple phylogenises produced (relaxed clock had some early nodes that branched quite differently, so I ran it twice) #DS
#
# Prior experience with pinning (Bohart, Bees, other classes [story: Jerusalem cricket locations and finds]) #Museum
#
# Eye for insects #Museum
#
# Summer Solstice #
#
# AgAsa (changing mind was too long a story?)?
#
# Academic clubs
#
# [darn it, I haven't done many instances of generate-product things]
#
# Constant journalling
#
# Learning programming?
#
# Planner story
#
# Getting a strong interest in Biorisk: Can I get a story out of this? #
#
#
#
# ## Stories
#
# I correctly sealed an SDS-PAGE gel the first time I was put in front of one (Ent dex advantage FTW!), and we were the only group in that class who did so correctly. #LAB
#
# Okay, so... tell me about yourself?
#
# Something you did, an interest you had?
#
#
# Oh hey, you write tons of sad stories. What if your life was a *happy* story? Write something up?

# %% [markdown]
# Summer Solstice story: Short w/ CAR
#
# Shorten to 3-5 sentences
#
# A community I'm associated with has a yearly event called the Secular Winter Solstice; it's a series of talks with  Humanist themes. Last year several people started talking about how great it would be to have a Summer Solstice event, but nobody seemed to be willing to run it. So I went ahead and picked it up. Reserved this nice site in Tilden, took care of food, that sort of thing. I suggested that everyone who came bring something interesting, and that worked out really well; there were slacklines, a ton of rubiks cubes, and somebody even brought a few boffer swords. People had a lot of fun.
#
# Big group of nerds, BBQ, set up food and site. Worked really well to have people bring something interesting, [things].
#
# Rationalists are people who come together to talk about cognitive biases
#
#
#
# Point story in directions?
